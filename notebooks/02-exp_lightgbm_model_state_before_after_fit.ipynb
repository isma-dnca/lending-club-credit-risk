# %%
model = LGBMClassifier(random_state=42)

# BEFORE FIT
print("Before fit:")
print(hasattr(model, "booster_"))  # False


model.fit(X_train, y_train)

# AFTER FIT
print("\nAfter fit:")
print(hasattr(model, "booster_"))  # True
