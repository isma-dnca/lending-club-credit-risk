# %%
DATA_DIR = PROJECT_ROOT/ "data"/"raw"
DATA_DIR
# Out:
# WindowsPath('C:/Users/Utilisateur/Desktop/2026/learning_and_career/coding/ML/lending-club-credit-risk/data/raw')

# %%
DATA_FILE = DATA_DIR / "LC_loans_granting_model_dataset.csv"
DATA_FILE
# Out:
# WindowsPath('C:/Users/Utilisateur/Desktop/2026/learning_and_career/coding/ML/lending-club-credit-risk/data/raw/LC_loans_granting_model_dataset.csv')

# %%
DATA_FILE.exists()
# Out:
# True

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Utilisateur\miniconda3\envs\lending-club-ml\python.exe

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\Utilisateur\\Desktop\\BOX\\2026\\learning_and_career\\coding\\ML\\lending-club-credit-risk\\notebooks'
